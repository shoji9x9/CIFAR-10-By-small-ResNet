# %% [markdown]
# # テーマ：CIFAR-10データセットを畳み込みニューラルネットワーク（CNN）で学習する

# %% [markdown]
# ## 制約
# * 全体の実行時間は60分以内

# %% [markdown]
# ## 今回参考にしたもの
# * [Deep Residual Learning for Image Recognition](https://arxiv.org/abs/1512.03385)
# * [practice on CIFAR10 with Keras](https://github.com/jerett/Keras-CIFAR10)

# %% [markdown]
# ## 0. Install TensorFlow 2.0

# %%
# !pip install tensorflow-gpu==2.0.0-alpha0
# Out:
# Requirement already satisfied: tensorflow-gpu==2.0.0-alpha0 in /usr/local/lib/python3.6/dist-packages (2.0.0a0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (3.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: tb-nightly<1.14.0a20190302,>=1.14.0a20190301 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.14.0a20190301)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.14.0.dev2019030115)
# Requirement already satisfied: google-pasta>=0.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.1.7)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.8.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.33.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.12.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.8)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.16.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-alpha0) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (0.15.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-alpha0) (2.8.0)

# %% [markdown]
# ## 1. Prepare dataset

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

# print(tfds.list_builders())
dataset, info = tfds.load('cifar10', as_supervised = True, with_info = True, batch_size = -1)
dataset_test, dataset_train = dataset['test'], dataset['train']
print(info)
# Out:
# tfds.core.DatasetInfo(
#     name='cifar10',
#     version=1.0.2,
#     description='The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.',
#     urls=['https://www.cs.toronto.edu/~kriz/cifar.html'],
#     features=FeaturesDict({
#         'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10)
#     },
#     total_num_examples=60000,
#     splits={
#         'test': <tfds.core.SplitInfo num_examples=10000>,
#         'train': <tfds.core.SplitInfo num_examples=50000>
#     },
#     supervised_keys=('image', 'label'),
#     citation='"""
#         @TECHREPORT{Krizhevsky09learningmultiple,
#             author = {Alex Krizhevsky},
#             title = {Learning multiple layers of features from tiny images},
#             institution = {},
#             year = {2009}
#         }
#
#     """',
#     redistribution_info=,
# )

# %%
import numpy as np

train_x = dataset_train[0] / 255
train_y = dataset_train[1]
test_x = dataset_test[0] / 255
test_y = dataset_test[1]

# Per-pixel Mean Subtraction
# mean_image = np.mean(train_x, axis=0)
# train_x -= mean_image
# test_x -= mean_image

# %% [markdown]
# ## 2. Data Augmentation

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

class CustomImageDataGenerator(ImageDataGenerator):
    def __init__(self, cutout_mask_size = 0, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.cutout_mask_size = cutout_mask_size
        
    def cutout(self, x, y):
        return np.array(list(map(self._cutout, x))), y
    
    def _cutout(self, image_origin):
        # 最後に使うfill()は元の画像を書き換えるので、コピーしておく
        image = np.copy(image_origin)
        mask_value = image.mean()

        h, w, _ = image.shape
        # マスクをかける場所のtop, leftをランダムに決める
        # はみ出すことを許すので、0以上ではなく負の値もとる(最大mask_size // 2はみ出す)
        top = np.random.randint(0 - self.cutout_mask_size // 2, h - self.cutout_mask_size)
        left = np.random.randint(0 - self.cutout_mask_size // 2, w - self.cutout_mask_size)
        bottom = top + self.cutout_mask_size
        right = left + self.cutout_mask_size

        # はみ出した場合の処理
        if top < 0:
            top = 0
        if left < 0:
            left = 0

        # マスク部分の画素値を平均値で埋める
        image[top:bottom, left:right, :].fill(mask_value)
        return image
    
    def flow(self, *args, **kwargs):
        batches = super().flow(*args, **kwargs)
        
        # 拡張処理
        while True:
            batch_x, batch_y = next(batches)
            
            if self.cutout_mask_size > 0:
                result = self.cutout(batch_x, batch_y)
                batch_x, batch_y = result                        
                
            yield (batch_x, batch_y)     

datagen_parameters = {"horizontal_flip": True, "width_shift_range": 0.1, "height_shift_range": 0.1, "cutout_mask_size": 16}
datagen = CustomImageDataGenerator(**datagen_parameters)
datagen_for_test = ImageDataGenerator()
# ZCA whiteningなどを行う場合が以下の実行が必要
# datagen.fit(train_x)
# datagen_for_test.fit(test_x)

# %% [markdown]
# ## 3. Define model

# %%
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Activation, MaxPool2D, GlobalAveragePooling2D, Add, Input, Flatten
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2

n = 9 # 56 layers
channels = [16, 32, 64]

inputs = Input(shape=(32, 32, 3))
x = Conv2D(channels[0], kernel_size=(3, 3), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation(tf.nn.relu)(x)

for c in channels:
    for i in range(n):
        subsampling = i == 0 and c > 16
        strides = (2, 2) if subsampling else (1, 1)
        y = Conv2D(c, kernel_size=(3, 3), padding="same", strides=strides, kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation(tf.nn.relu)(y)
        y = Conv2D(c, kernel_size=(3, 3), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)        
        if subsampling:
            x = Conv2D(c, kernel_size=(1, 1), strides=(2, 2), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(x)
        x = Add()([x, y])
        x = Activation(tf.nn.relu)(x)

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
outputs = Dense(10, activation=tf.nn.softmax, kernel_initializer="he_normal")(x)

model = Model(inputs=inputs, outputs=outputs)
model.type = "resnet" + str(6 * n + 2)

# %%
from io import StringIO
import re

with StringIO() as buf:
    model.summary(print_fn=lambda x: buf.write(x + "\n"))
    summary = buf.getvalue()
print(summary)
re1 = re.match(r"(.|\s)*Total params: ", summary)
re2 = re.match(r"(.|\s)*Total params: [\d|,]+", summary)
total_params = summary[re1.end():re2.end()]
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_55 (Batc (None, 32, 32, 16)   64          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 16)   2320        activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_56 (Batc (None, 32, 32, 16)   64          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 16)   2320        activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_57 (Batc (None, 32, 32, 16)   64          conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 32, 32, 16)   0           activation_55[0][0]
#                                                                  batch_normalization_v2_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 16)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 16)   2320        activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_58 (Batc (None, 32, 32, 16)   64          conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 16)   2320        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_59 (Batc (None, 32, 32, 16)   64          conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 32, 32, 16)   0           activation_57[0][0]
#                                                                  batch_normalization_v2_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 16)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 16)   2320        activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_60 (Batc (None, 32, 32, 16)   64          conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 16)   2320        activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_61 (Batc (None, 32, 32, 16)   64          conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 32, 32, 16)   0           activation_59[0][0]
#                                                                  batch_normalization_v2_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 16)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 16)   2320        activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_62 (Batc (None, 32, 32, 16)   64          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 16)   2320        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_63 (Batc (None, 32, 32, 16)   64          conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32, 32, 16)   0           activation_61[0][0]
#                                                                  batch_normalization_v2_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 16)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 16)   2320        activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_64 (Batc (None, 32, 32, 16)   64          conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 16)   2320        activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_65 (Batc (None, 32, 32, 16)   64          conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 32, 16)   0           activation_63[0][0]
#                                                                  batch_normalization_v2_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 16)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 16)   2320        activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_66 (Batc (None, 32, 32, 16)   64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_66[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 16)   2320        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_67 (Batc (None, 32, 32, 16)   64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 32, 16)   0           activation_65[0][0]
#                                                                  batch_normalization_v2_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 16)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 16)   2320        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_68 (Batc (None, 32, 32, 16)   64          conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 16)   2320        activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_69 (Batc (None, 32, 32, 16)   64          conv2d_71[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 32, 32, 16)   0           activation_67[0][0]
#                                                                  batch_normalization_v2_69[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 16)   0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 16)   2320        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_70 (Batc (None, 32, 32, 16)   64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 16)   2320        activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_71 (Batc (None, 32, 32, 16)   64          conv2d_73[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 32, 32, 16)   0           activation_69[0][0]
#                                                                  batch_normalization_v2_71[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 16)   0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 16)   2320        activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_72 (Batc (None, 32, 32, 16)   64          conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 32, 32, 16)   0           batch_normalization_v2_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 16)   2320        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_73 (Batc (None, 32, 32, 16)   64          conv2d_75[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 32, 32, 16)   0           activation_71[0][0]
#                                                                  batch_normalization_v2_73[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 32, 32, 16)   0           add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 32)   4640        activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_74 (Batc (None, 16, 16, 32)   128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 16, 32)   9248        activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 32)   544         activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_75 (Batc (None, 16, 16, 32)   128         conv2d_77[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 16, 16, 32)   0           conv2d_78[0][0]
#                                                                  batch_normalization_v2_75[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 16, 32)   0           add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 32)   9248        activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_76 (Batc (None, 16, 16, 32)   128         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_76[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 32)   9248        activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_77 (Batc (None, 16, 16, 32)   128         conv2d_80[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 16, 16, 32)   0           activation_75[0][0]
#                                                                  batch_normalization_v2_77[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 16, 16, 32)   0           add_37[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 32)   9248        activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_78 (Batc (None, 16, 16, 32)   128         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_78[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 32)   9248        activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_79 (Batc (None, 16, 16, 32)   128         conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 16, 16, 32)   0           activation_77[0][0]
#                                                                  batch_normalization_v2_79[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 16, 16, 32)   0           add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 32)   9248        activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_80 (Batc (None, 16, 16, 32)   128         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_80[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 32)   9248        activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_81 (Batc (None, 16, 16, 32)   128         conv2d_84[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 16, 16, 32)   0           activation_79[0][0]
#                                                                  batch_normalization_v2_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 16, 16, 32)   0           add_39[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 32)   9248        activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_82 (Batc (None, 16, 16, 32)   128         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_82[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 32)   9248        activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_83 (Batc (None, 16, 16, 32)   128         conv2d_86[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 16, 16, 32)   0           activation_81[0][0]
#                                                                  batch_normalization_v2_83[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 16, 16, 32)   0           add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 32)   9248        activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_84 (Batc (None, 16, 16, 32)   128         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_84[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 32)   9248        activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_85 (Batc (None, 16, 16, 32)   128         conv2d_88[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 16, 16, 32)   0           activation_83[0][0]
#                                                                  batch_normalization_v2_85[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 16, 16, 32)   0           add_41[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 32)   9248        activation_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_86 (Batc (None, 16, 16, 32)   128         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_86[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 32)   9248        activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_87 (Batc (None, 16, 16, 32)   128         conv2d_90[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 16, 16, 32)   0           activation_85[0][0]
#                                                                  batch_normalization_v2_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 16, 16, 32)   0           add_42[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 16, 16, 32)   9248        activation_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_88 (Batc (None, 16, 16, 32)   128         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_88[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 16, 16, 32)   9248        activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_89 (Batc (None, 16, 16, 32)   128         conv2d_92[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 16, 16, 32)   0           activation_87[0][0]
#                                                                  batch_normalization_v2_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 16, 16, 32)   0           add_43[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 16, 16, 32)   9248        activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_90 (Batc (None, 16, 16, 32)   128         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 16, 16, 32)   0           batch_normalization_v2_90[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 16, 16, 32)   9248        activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_91 (Batc (None, 16, 16, 32)   128         conv2d_94[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 16, 16, 32)   0           activation_89[0][0]
#                                                                  batch_normalization_v2_91[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 16, 16, 32)   0           add_44[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 8, 8, 64)     18496       activation_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_92 (Batc (None, 8, 8, 64)     256         conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 64)     0           batch_normalization_v2_92[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 8, 8, 64)     36928       activation_92[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 8, 8, 64)     2112        activation_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_93 (Batc (None, 8, 8, 64)     256         conv2d_96[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 8, 8, 64)     0           conv2d_97[0][0]
#                                                                  batch_normalization_v2_93[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 64)     0           add_45[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 8, 8, 64)     36928       activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_94 (Batc (None, 8, 8, 64)     256         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 8, 8, 64)     0           batch_normalization_v2_94[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 8, 8, 64)     36928       activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_95 (Batc (None, 8, 8, 64)     256         conv2d_99[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 8, 8, 64)     0           activation_93[0][0]
#                                                                  batch_normalization_v2_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 8, 8, 64)     0           add_46[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 8, 8, 64)     36928       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_96 (Batc (None, 8, 8, 64)     256         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 8, 8, 64)     0           batch_normalization_v2_96[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 8, 8, 64)     36928       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_97 (Batc (None, 8, 8, 64)     256         conv2d_101[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 8, 8, 64)     0           activation_95[0][0]
#                                                                  batch_normalization_v2_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 8, 8, 64)     0           add_47[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 8, 8, 64)     36928       activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_98 (Batc (None, 8, 8, 64)     256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 8, 8, 64)     0           batch_normalization_v2_98[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 8, 8, 64)     36928       activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_99 (Batc (None, 8, 8, 64)     256         conv2d_103[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 8, 8, 64)     0           activation_97[0][0]
#                                                                  batch_normalization_v2_99[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 8, 8, 64)     0           add_48[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 8, 8, 64)     36928       activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_100 (Bat (None, 8, 8, 64)     256         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 8, 8, 64)     0           batch_normalization_v2_100[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 8, 8, 64)     36928       activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_101 (Bat (None, 8, 8, 64)     256         conv2d_105[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 8, 8, 64)     0           activation_99[0][0]
#                                                                  batch_normalization_v2_101[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 8, 8, 64)     0           add_49[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 8, 8, 64)     36928       activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_102 (Bat (None, 8, 8, 64)     256         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 8, 8, 64)     0           batch_normalization_v2_102[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 8, 8, 64)     36928       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_103 (Bat (None, 8, 8, 64)     256         conv2d_107[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 8, 8, 64)     0           activation_101[0][0]
#                                                                  batch_normalization_v2_103[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 8, 8, 64)     0           add_50[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 8, 8, 64)     36928       activation_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_104 (Bat (None, 8, 8, 64)     256         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 8, 8, 64)     0           batch_normalization_v2_104[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 8, 8, 64)     36928       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_105 (Bat (None, 8, 8, 64)     256         conv2d_109[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 8, 8, 64)     0           activation_103[0][0]
#                                                                  batch_normalization_v2_105[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 8, 8, 64)     0           add_51[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 8, 8, 64)     36928       activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_106 (Bat (None, 8, 8, 64)     256         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 8, 8, 64)     0           batch_normalization_v2_106[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 8, 8, 64)     36928       activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_107 (Bat (None, 8, 8, 64)     256         conv2d_111[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 8, 8, 64)     0           activation_105[0][0]
#                                                                  batch_normalization_v2_107[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 8, 8, 64)     0           add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 8, 8, 64)     36928       activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_108 (Bat (None, 8, 8, 64)     256         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 8, 8, 64)     0           batch_normalization_v2_108[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 8, 8, 64)     36928       activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_109 (Bat (None, 8, 8, 64)     256         conv2d_113[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 8, 8, 64)     0           activation_107[0][0]
#                                                                  batch_normalization_v2_109[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 8, 8, 64)     0           add_53[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           activation_109[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 861,770
# Trainable params: 857,706
# Non-trainable params: 4,064
# __________________________________________________________________________________________________

# %% [markdown]
# ## 4. Prepare training

# %%
from tensorflow.keras.optimizers import Adam, SGD

# lr = 0.001
# optimizer = Adam(learning_rate=lr)
lr = 0.1
optimizer = SGD(learning_rate=lr, momentum=0.9)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# !pip install hyperdash
from hyperdash import monitor_cell
# !hyperdash signup --github

# %%
from hyperdash import Experiment
exp = Experiment("ResNet-for-CIFAR-10-with-Keras")

# %%
from tensorflow.keras.callbacks import Callback
import time

class Hyperdash(Callback):
    def __init__(self, entries, exp):
        super(Hyperdash, self).__init__()
        self.entries = entries
        self.exp = exp

    def on_epoch_end(self, epoch, logs=None):
        for entry in self.entries:
            log = logs.get(entry)            
            if log is not None:
                self.exp.metric(entry, log)

class LearningController(Callback):
    def __init__(self, num_epoch=0, learn_minute=0):
        self.num_epoch = num_epoch
        self.learn_second = learn_minute * 60
        if self.learn_second > 0:
            print("Leraning rate is controled by time.")
        elif self.num_epoch > 0:
            print("Leraning rate is controled by epoch.")
        
    def on_train_begin(self, logs=None):
        if self.learn_second > 0:
            self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        if self.learn_second > 0:
            current_time = time.time()
            if current_time - self.start_time > self.learn_second:
                self.model.stop_training = True
                print("Time is up.")
                return

            if current_time - self.start_time > self.learn_second / 2:
                self.model.optimizer.lr = lr * 0.1            
            if current_time - self.start_time > self.learn_second * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                
        elif self.num_epoch > 0:
            if epoch > self.num_epoch / 2:
                self.model.optimizer.lr = lr * 0.1            
            if epoch > self.num_epoch * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                    
        print('lr:%.2e' % self.model.optimizer.lr.value())

# %%
num_epoch = 182
learn_minute = 120

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

hyperdash = Hyperdash(["val_loss", "loss", "val_accuracy", "accuracy"], exp)
checkpoint = ModelCheckpoint(filepath = "ResNet-for-CIFAR-10-with-Keras.h5", monitor="val_loss", verbose=1, save_best_only=True)
learning_controller = LearningController(num_epoch)
callbacks = [hyperdash, checkpoint, learning_controller]

# %% [markdown]
# ## 5. Train

# %%
batch_size = 128
number_train = info.splits["train"].num_examples
number_test = info.splits["test"].num_examples

# %%
import json

exp.param("Model type", model.type)
exp.param("Total params", total_params)
exp.param("Optimizer", optimizer)
exp.param("Leraning rate", lr)
exp.param("Datagen", json.dumps(datagen_parameters))
exp.param("Batch size", batch_size)
exp.param("Number of epoch", num_epoch)
exp.param("Learn minute", learn_minute)
# Out:
# 120

# %%
history = model.fit(datagen.flow(train_x, train_y, batch_size=batch_size), 
                    epochs=num_epoch, 
                    steps_per_epoch=number_train//batch_size, 
                    validation_data=datagen_for_test.flow(test_x, test_y, batch_size=batch_size), 
                    validation_steps=number_test//batch_size,
                    verbose=0,                    
                    callbacks=callbacks)
exp.end()

# %% [markdown]
# ## 6. Show transition of accuracy

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"], label = 'Train Accuracy')
plt.plot(history.history["val_accuracy"], linestyle = 'dashed', label = 'Test Accuracy')
plt.legend()
plt.show()

# %%
model.evaluate(test_x, test_y)
# Out:
# 10000/10000 [==============================] - 3s 323us/sample - loss: 0.3844 - accuracy: 0.9358
# [0.3843775578975677, 0.9358]
